# %%
import pandas as pd

# %%
# Visualization
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
sns.set()

# %%
PREPROCESSED_DATA_PATH = 'data/2_preprocessed/'

# %%
dl_file = 'tweets_join_df_1596630.csv'
tweets_df = pd.read_csv(PREPROCESSED_DATA_PATH + dl_file, index_col=0)

# %%
tweets_df.sample(5)
# Out:
#          label                                               text  \
# 1425496      1  @graywolf So that means we have to trust what ...
# 929976       1                          @souljaboytellem Bye Boy
# 1430833      1  {If I need intellectual stimulation motha fuck...
# 1006038      1  yay got my ups all plugged in. 16 hrs later i ...
# 1559791      1  @brookecondolora Ha ha! That was a cool little...
#
#                                                      clean  \
# 1425496  user so that means we have to trust what is on...
# 929976                                        user bye boy
# 1430833  if i need intellectual stimulation motha fucka...
# 1006038  yay got my ups all plugged in 16 hrs later i c...
# 1559791            user ha ha that was a cool little video
#
#                                                  clean_lem  \
# 1425496  user so that means we have to trust what is on...
# 929976                                        user bye boy
# ...

# %% [markdown]
# ## Visualize data

# %%
corpus = " ".join(tweets_df.clean)

# %%
wordcloud = WordCloud(background_color='white',
                      width=1600,
                      height=800, 
                      collocations=False,
                      max_words=50).generate(corpus)
plt.imshow(wordcloud)
plt.axis("off")
plt.show();

# %%
bad_corpus = " ".join(tweets_df[tweets_df.label==0].clean)

# %%
wordcloud = WordCloud(background_color='white',
                      width=1600,
                      height=800,
                      collocations=False,
                      max_words=50).generate(bad_corpus)
plt.imshow(wordcloud)
plt.axis("off")
plt.show();

# %%
good_corpus = " ".join(tweets_df[tweets_df.label==1].clean)

# %%
wordcloud = WordCloud(background_color='white',
                      width=1600,
                      height=800,
                      collocations=False,
                      max_words=50).generate(good_corpus)
plt.imshow(wordcloud)
plt.axis("off")
plt.show();
